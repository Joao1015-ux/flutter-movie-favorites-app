# %% [markdown]
# <a href="https://colab.research.google.com/github/Joao1015-ux/flutter-movie-favorites-app/blob/main/Jogo_Trabalho_da_APS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# World Magic Adventures

# %%
nome = str(input('digite seu nome: '))

print(' 1 - Cavaleiro: um humano forte e corajoso com uma armadura poderosa e uma boa espada (seu objetivo é resgatar ''uma princesa)\n 2 - Mago: um feiticeiro poderoso, muito esperto e corajoso (seu objetivo é pegar uma pedra ''poderosa para os seus feitiços)\n 3 - Troll: uma criatura gigante e com uma força bruta gigantesca mais não ''muito esperto (seu objetivo não passa de um banquete com comida de sabor incrivel)\n 4 - Elfo: Criatura mística. Conhecidos por sua agilidade, sabedoria ancestral e habilidades mágicas. (Seu objetivo é recuperar um antigo artefato élfico, escondido em uma floresta encantada, que possui o poder de restaurar tudo o que quiser.)\n 5 - Desisitir da jornada!')
op = int(input('escolha um persongem: '))

while True:

    if op == 1:
        print(f'Parabens mais novo e incrivel cavaleiro!!!')
        print("Você entrou na floresta! Mas agora encontrou um caminho de goblins!")
        print("1. Lutar contra os goblins.")
        print("2. Tentar negociar com eles.")
        escolha_goblins = int(input("O que você vai fazer? "))

        if escolha_goblins == 1:
            print("Você luta bravamente contra os goblins!")
            print("Depois de uma batalha intensa, você consegue derrotá-los e encontra um lago mágico.")
            print("1. Usar a água mágica do lago para aumentar sua força.")
            print("2. Ignorar o lago e continuar seu caminho.")
            escolha_lago = int(input("O que você faz? "))

            if escolha_lago == 1:
                print("Você bebe a água mágica e se sente mais forte!")
                print("Com a nova força, você continua sua jornada e chega ao castelo do dragão.")
                print("No castelo, o dragão está esperando.")
                print("1. Lutar com todas as suas forças.")
                print("2. Tentar fazer um acordo com o dragão.")
                escolha_dragao = int(input("O que você faz? "))

                if escolha_dragao == 1:
                    print("Você enfrenta o dragão com toda a força adquirida e vence a batalha!")
                    print(f"Parabéns, {nome}! Você salvou a princesa e se tornou um verdadeiro herói!")
                elif escolha_dragao == 2:
                    print("Você tenta negociar com o dragão e, surpreendentemente, ele concorda em libertar a princesa!")
                    print(f"Parabéns, {nome}! Você salvou a princesa sem lutar!")
                else:
                    print("Escolha inválida. O dragão se irrita e você precisa sair correndo!")

            elif escolha_lago == 2:
                print("Você decide ignorar o lago mágico e continuar seu caminho.")
                print("Enquanto avança, você chega ao castelo do dragão.")
                print("O dragão está esperando por você, pronto para a batalha!")
                print("1. Lutar com todas as suas forças.")
                print("2. Tentar fazer um acordo com o dragão.")
                escolha_dragao = int(input("O que você faz? "))

                if escolha_dragao == 1:
                    print("Você enfrenta o dragão com toda a força que tem!")
                    print("A batalha é intensa e feroz, mas você luta bravamente.")
                    print("Após uma luta difícil, você consegue derrotar o dragão!")
                    print(f"Parabéns, {nome}! Você salvou a princesa e se tornou um verdadeiro herói!")
                elif escolha_dragao == 2:
                    print("Você tenta fazer um acordo com o dragão.")
                    print("Surpreendentemente, o dragão concorda em libertar a princesa em troca de um tesouro.")
                    print("Você rapidamente oferece um tesouro que encontrou na floresta.")
                    print(f"Parabéns, {nome}! Você salvou a princesa sem lutar e conseguiu paz com o dragão!")
                else:
                    print("Escolha inválida. O dragão se irrita e você precisa sair correndo!")

        elif escolha_goblins == 2:
            print("Os goblins aceitam negociar e te mostram um atalho! Você avança para salvar a princesa.")
            print("Você segue pelo atalho e encontra um lago mágico.")
            print("1. Usar a água mágica do lago para aumentar sua força.")
            print("2. Ignorar o lago e continuar seu caminho.")
            escolha_lago = int(input("O que você faz? "))

            if escolha_lago == 1:
                print("Você bebe a água mágica e se sente mais forte!")
                print("Com a nova força, você continua sua jornada e chega ao castelo do dragão.")
                print("No castelo, o dragão está esperando.")
                print("1. Lutar com todas as suas forças.")
                print("2. Tentar fazer um acordo com o dragão.")
                escolha_dragao = int(input("O que você faz? "))

                if escolha_dragao == 1:
                    print("Você enfrenta o dragão com toda a força adquirida e vence a batalha!")
                    print(f"Parabéns, {nome}! Você salvou a princesa e se tornou um verdadeiro herói!")
                elif escolha_dragao == 2:
                    print("Você tenta negociar com o dragão e, surpreendentemente, ele concorda em libertar a princesa!")
                    print(f"Parabéns, {nome}! Você salvou a princesa sem lutar!")
                else:
                    print("Escolha inválida. O dragão se irrita e você precisa sair correndo!")

            elif escolha_lago == 2:
                print("Você decide ignorar o lago mágico e continuar seu caminho.")
                print("Enquanto avança, você chega ao castelo do dragão.")
                print("O dragão está esperando por você, pronto para a batalha!")
                print("1. Lutar com todas as suas forças.")
                print("2. Tentar fazer um acordo com o dragão.")
                escolha_dragao = int(input("O que você faz? "))

                if escolha_dragao == 1:
                    print("Você enfrenta o dragão com toda a força que tem!")
                    print("A batalha é intensa e feroz, mas você luta bravamente.")
                    print("Após uma luta difícil, você consegue derrotar o dragão!")
                    print(f"Parabéns, {nome}! Você salvou a princesa e se tornou um verdadeiro herói!")
                elif escolha_dragao == 2:
                    print("Você tenta fazer um acordo com o dragão.")
                    print("Surpreendentemente, o dragão concorda em libertar a princesa em troca de um tesouro.")
                    print("Você rapidamente oferece um tesouro que encontrou na floresta.")
                    print(f"Parabéns, {nome}! Você salvou a princesa sem lutar e conseguiu paz com o dragão!")
                else:
                    print("Escolha inválida. O dragão se irrita e você precisa sair correndo!")

                    if escolha == 2:
                         print("Você escolheu o caminho montanhoso e subiu até o pico mais alto, onde se depara com o dragão!")
                         print("1. Enfrentar o dragão com sua espada.")
                         print("2. Tentar distraí-lo para resgatar a princesa.")
                         escolha_dragao = int(input("O que você faz? "))

                    if escolha_dragao == 1:
                      print("Você avança contra o dragão com sua espada em punho!")
                      print("Após uma batalha intensa, você vê uma armadura brilhante ao lado do dragão.")
                      print("1. Pegar a armadura e continuar a luta.")
                      print("2. Ignorar a armadura e focar em derrotar o dragão.")
                      escolha_armadura = int(input("Qual é a sua escolha? "))

                    if escolha_armadura == 1:
                       print("A armadura mágica aumenta sua defesa! Com sua nova força, você consegue derrotar o dragão!")
                       print(f"Parabéns, {nome}! Você derrotou o dragão e resgatou a princesa!")
                    elif escolha_armadura == 2:
                       print("Você ignora a armadura e luta com todas as suas forças!")
                       print("Infelizmente, sem a armadura, você é atingido por um ataque do dragão e precisa recuar.")
                       print("De volta à cidade, você se prepara para uma nova tentativa no futuro.")
                    else:
                       print("Escolha inválida. O dragão ataca enquanto você hesita!")

        elif escolha_dragao == 2:
          print("Você decide tentar distrair o dragão com uma manobra astuta.")
          print("Ao distrair o dragão, você encontra uma entrada secreta para o castelo.")
          print("1. Entrar no castelo pela passagem secreta.")
          print("2. Aproveitar a distração e atacar o dragão de surpresa.")
          escolha_passagem = int(input("Qual é a sua escolha? "))

          if escolha_passagem == 1:
            print("Você entra no castelo e encontra a princesa presa em uma torre!")
            print("1. Resgatar a princesa imediatamente.")
            print("2. Procurar uma saída alternativa antes de resgatá-la.")
            escolha_resgate = int(input("O que você faz? "))

            if escolha_resgate == 1:
                print("Você resgata a princesa com sucesso e foge antes que o dragão perceba!")
                print(f"Parabéns, {nome}! Você salvou a princesa e se tornou um verdadeiro herói!")
            elif escolha_resgate == 2:
                print("Ao procurar uma saída alternativa, você encontra um tesouro mágico!")
                print("Com a ajuda do tesouro, você derrota o dragão e foge com a princesa em segurança!")
                print(f"Parabéns, {nome}! Você salvou a princesa e trouxe um tesouro para a cidade!")
            else:
                print("Escolha inválida. O dragão percebe sua presença e você precisa fugir!")

        elif escolha_passagem == 2:
            print("Você ataca o dragão de surpresa!")
            print("O dragão é pego desprevenido, e você consegue feri-lo!")
            print("1. Continuar atacando para derrotá-lo.")
            print("2. Aproveitar o momento para resgatar a princesa e fugir.")
            escolha_fuga = int(input("Qual é a sua escolha? "))

            if escolha_fuga == 1:
                print("Você luta bravamente e consegue derrotar o dragão!")
                print(f"Parabéns, {nome}! Você salvou a princesa e se tornou um herói lendário!")
            elif escolha_fuga == 2:
                print("Você decide fugir com a princesa enquanto o dragão está ferido.")
                print("Felizmente, você escapa com sucesso, e a cidade celebra sua bravura!")
                print(f"Parabéns, {nome}! Você salvou a princesa e garantiu a paz!")
            else:
                print("Escolha inválida. O dragão se recupera e você precisa recuar!")


    elif op == 2:
        print(f'Parabens você agora é um mago em ascensão!!!')
        print('Sua missão é enfrentar o terrível Mago Plarios e com isso obter o poder de criar artefatos com poder imensurável!')
        print('Você está preparado? se sim, digite "s" ou se não "n" ')
        escolha_mago = input('').lower()

        if escolha_mago in "s":
            print('Meus parabens meu exímio mago!')
            print('Esteja preparado para enfrentar grandes desafios seja sábio em cada decisão')
            print('Em sua primeira jornada para enfrentar  o terrível Mago Plarios. Este mago é terrível e cruel, ele matou seus irmãos e arrasou sua cidade natal buscando você....')
            print('Bem,há um bosque que antecede a caverna de plarios')
            print('Acerca desse bosque pouco se sabe o que acontece lá, dizem que lá habitam Trolls, Gigantes e todo tipo de criatura maligna, crueis, e impetuosos!, e claro, tesouros! .')
            print('Para prosseguir sua viagem há uma outra possibilidade também, que é contornar o bosque, um caminho razoavelmente seguro')
            print('Agora faça sua escolha \n 1) Ir pelo bosque. \n 2) contornar o bosque.')
            caminho = int(input(''))

        if caminho == 1:
            print('ok!')
            print("Passando pelo bosque você se depara com um baita gigante em sua frente o que você faz?")
            print('1) Mata')
            print('2) Foge')
            caminho_1 = int(input(''))

            if caminho_1 == 1:
                print('Boa escolha!')
                print('Graças a sua experiência em combate e coragem você venceu aquele gigante execrável!')
                print('Com isso adquire 50 moedas de ouro')
                print('Bora seguir viagem.')
                print('Conforme o andar da carroagem você enfrenta alguns inimigos, e os vence com facilidade (você o cara! / boa garota!), \n até que você chega ao final do bosque e logo pode ver o castelo.')
                print('Mas espera! você encontrou um mercador! o que será que ele tem a oferecer?')
                print('Certo, é hora de agir!')
                print('E agora o que você irá fazer? dar um olhadinha ou ir direto para o desafio final? escolha uma alternativa')
                print('1) Ver mercadorias \n 2) Ir direto ao ponto.')
                parte_1 = int(input(' '))
                if parte_1 == 1:
                    print('ok')
                    print('Vamos seguir viagem!')
                    for i in range(5):
                        print('...')

                    print('Chegando no mercado há 4 opções')
                    print(' 1) Espada de ferro')
                    print(' 2) Lança de aço')
                    print(' 3) Poção de vida')
                    print(' 4) Poção de mana')
                    parte_2 = int(input(' '))

                    if parte_2 == 1:
                        print('Boa escolha!')
                        print('Bem, agora se prepare para o confronto final! ')
                        print('Pronto, agora equipe-se, reze, e avante.')
                        print('Eis ai o grande e temível Plarios, o terrível!')
                        print('Você entrou na caverna, agora se prepare e lute!')

                        for i in range(3):
                            print('argh........')
                            print('receba essa!')

                            print(f'Oh, não {nome}, esse mago é muito forte! Infelizmente você não foi pareo.')
                            print('GAME OVER')
                            break


                    elif parte_2 == 2:
                        print('Boa escolha!')
                        print('Bem, agora se prepare para o confronto final! ')
                        print('Pronto, agora equipe-se, reze, e avante.')
                        print('Eis ai o grande e temível Plarios, o terrível!')
                        print('Você entrou na caverna, agora se prepare e lute!')
                        for i in range(3):
                            print('argh........')
                            print('receba essa!')

                            print(f'Oh, não {nome}, esse mago é muito forte! Infelizmente você não foi pareo.')
                            break

                    elif parte_2 == 3:
                        print('Boa escolha!')
                        print('Bem, agora se prepare para o confronto final! ')
                        print('Pronto, agora equipe-se, reze, e avante.')
                        print('Eis ai o grande e temível Plarios, o terrível!')
                        print('Você entrou na caverna, agora se prepare e lute!')

                        for i in range(3):
                            print('argh........')
                            print('receba essa!')

                            print(f' Uau {nome} você é incrivel, conseguir derrotar Plarios, o terrível! e agora é o mago mais forte existente, e também o mais rico, congratulations my friend, VOCÊ VENCEU!')
                            break

                    elif parte_2 == 4:
                     print('Boa escolha!')
                     print('Bem, agora se prepare para o confronto final! ')
                     print('Pronto, agora equipe-se, reze, e avante.')
                     print('Eis ai o grande e temível Plarios, o terrível!')
                     print('Você entrou na caverna, agora se prepare e lute!')

                    for i in range(3):
                        print('argh........')
                        print('receba essa!')

                        print(f'Oh, não {nome}, esse mago é muito forte! Infelizmente você não foi pareo.')
                        print('GAME OVER')
                        break


                elif parte_1 == 2:
                    print('ok, você decicdiu ir direto ao ponto')
                    print('Vamos seguir viagem!')
                    print('Prosseguindo viagem você vê a caverna de Plario, o terrível, e então decide seguir viagem ')
                    print('Agora você está entrando na caverna')
                    print('Entrando na caverna você se deparacom aquele mago asqueroso e decide vingar seus irmãos, sua família, e sua cidade pela maldade deste mago impiedoso!')
                    print('Inicia-se a batalha')
                    print(f'Oh, não {nome}, esse mago é muito forte! Infelizmente você não foi pareo.')
                    print('GAME OVER')
                    break

            if caminho == 2:
                print('Boa!')
                print('Ao contornar o bosque você se depara com um pequeno cachorro machucado no caminho')
                print('você, ajuda ele gastando seus recursos preciosos com ele ou segue viagem?')
                print('ok')
                print('depois de auxiliar o cachorro em seus ferimentos, você sai em busca da sua jornada')
                print('até que em um certo momento ouve um barulho. obs: alguém está te seguindo')
                print('Antes de você disparar uma enorme bola de fogo, você percebe que é o cachorro que acabara de que acabara se despedir')
                print('prosseguindo viagem você vê a caverna de Plario, o terrível, e então decide seguir viagem ')
                print('Agora você está entrando na caverna')
                print('Entrando na caverna você se deparacom aquele mago asqueroso e decide vingar seus irmãos, sua família, e sua cidade pela maldade deste mago impiedoso!')
                print('Inicia-se a batalha')
                print('argh........')
                print('receba essa!')
                print('oh não, seu cachorro morreu!')
                print('os não você está faco demais para lutar')
                print('ah, não cara, você estava tão perto, poxa, não foi dessa vez!')
                print('GAME OVER')


        elif caminho_1 == 2:
            print('oh, não você tentou escapar mas o gigante te viu e num piscar de olhos, te comeu! que pena, GAME OVER!')



        elif escolha_mago in "n":
            print('Decepcionante, pensei que você era um mago, você não defende a honra da sua família? Lastimável!, sabe o que te falta? ódio!')
            break
        elif escolha_mago in "nao":
            print('Decepcionante, pensei que você era um mago, você não defende a honra da sua família? Lastimável!, sabe o que te falta? ódio!')
            break
        elif escolha_mago in "não":
            print('Decepcionante, pensei que você era um mago, você não defende a honra da sua família? Lastimável!, sabe o que te falta? ódio!')
            break


    if op == 3:
        print(f'Parabens você tomou uma poção e agora é um troll gigante!!!')
        print(f'Você esta em caminhis divididos')
        print('1- Caminhos das rochas.')
        print('2- Passar pela planice das rosas.')

        escolha = int(input(f'Qual caminho você ira seguir: '))

        if escolha == 1:
            print('Você foi pelo caminho das rochas. Mais a frente você encontra um golem maior que você!!!')
            print('1-Primeira escolha: Lutar no mano a mano com ele.')
            print('2-Segunda escolha: Você vence ele atacando pedras imensas que estão ao seu redor.')

            escolha_rochas = int(input('O que você vai fazer: '))

            if escolha_rochas == 1:
                print('Você começa a batalha contra ele')
                print('Com muito esforço você descobre seu ponto fraco em baixo do queixo')
                print('Você desfere um golpe poderoso no ponto fraco e vence a luta.')


            elif escolha_rochas == 2:
                print('Olhando a sua volta tem pedras pesadas.')
                print('Você pega as pedras com sua força e mira.')
                print('Jogando algumas pedras ele cai derrotado.')

            print('Caminhando pela planice você avista uma mansão')
            print('Entrando na casa você vê uma miragem de alguém do seu passado que já se foi')
            print('1- Falar com a miragem mesmo sabendo a verdade')
            print('2- Ignorar a miragem e seguir seu objetivo.')

            escolha_final = int(input('O que você escolhe: '))

            if escolha_final == 1:
                print('A miragem toma seu tempo mostrando lembranças mais logo acabam e ela sobe abrindo seu caminho.\n Seguindo a sala você chega ao seu banquete e se delicia com a conquista de seu objetivo.')
            elif escolha_final == 2:
                print('Você atravessa a miragem e segue seu caminho um pouco cabisbaixo.\n Chegou ao seu banquete e vendo aquilo sua curta memoria de TROLL esquece o que aconteceu instantes atraz então você come tranquilamente.')
            break

        elif escolha == 2:
            print('Caminhando pela planice você avista uma mansão')
            print('Entrando na casa você vê uma miragem de alguém do seu passado que já se foi')
            print('1- Falar com a miragem mesmo sabendo a verdade')
            print('2- Ignorar a miragem e seguir seu objetivo.')

            escolha_final = int(input('O que você escolhe: '))

            if escolha_final == 1:
                print('A miragem toma seu tempo mostrando lembranças mais logo acabam e ela sobe abrindo seu caminho.\n Seguindo a sala você chega ao seu banquete e se delicia com a conquista de seu objetivo.')
            elif escolha_final == 2:
                print('Você atravessa a miragem e segue seu caminho um pouco cabisbaixo.\n Chegou ao seu banquete e vendo aquilo sua curta memoria de TROLL esquece o que aconteceu instantes atraz')
            break

    if op == 4:
            print(f'Parabens, lhe foi concebido um poder pelo universo e agora é um Elfo!!!')
            print(f'Você esta em caminhos divididos')
            print('1- Atravessar o Reino.')
            print('2- Adentrar um prtal que te levará para a dimensão elfica.')

            escolha = int(input(f'Qual caminho você ira seguir: '))

            if escolha == 1:
             print('Você foi pelo caminho do reino. Cuidado! E se disfarce entre os humanos...')
             print('1-Primeira escolha: Usar um feitiço e se transformar em um humano.')
             print('2-Segunda escolha: Lançar uma magia de esquecimento em todos aqueles que te verem.')

             escolha_reino = int(input('O que você vai fazer: '))

             if escolha_reino == 1:
                print('Você usa a magia élfica e se torna temporariamente em um humano.')
                print('É chato se parecer com esses seres inferiores, mas você se sai bem!')
                print('Graças a essa magia você está seguro no reino.')

             elif escolha_reino == 2:
                print('Humanos te vêem e se assustam.')
                print('Antes que possam falar sobre, você os lança a magia de esquecimento e eles não se lembram do que acabaram de ver.')
                print('É uma tática arriscada, mas ainda está seguro...')
                print('Você encontra a passagem secreta no reino e vai direto para a dimensão élfica.')

            print('Você está na dimensão élfica')
            print('No meio daquele paraíso você vê o seu almejado objetivo')
            print('1- Agarrar o artefato élfico e obter o seu poder. ')
            print('2- Repensar e desistir de um poder tão grande.')

            escolha_final = int(input('O que você escolhe: '))

            if escolha_final == 1:
                print('Você agarra o artefato, mas o seu poder é grande demais para qualquer ser vivo. O jogo virou contra você e você morreu! GAME OVER.')
                break
            elif escolha_final == 2:
                print('O universo admira a sua sagacidade. o poder da pedra é inconcebível para qualquer ser vivo. Mas como recompensa por sua nobreza, o universo t torna um elfo de classe ômega, com poderes muito maiores do que os de um elfo comum..')
                break
            elif escolha == 2:
             print('Você poupa o esforço de passar pelo reino, mas o portal não te leva exatamente para a dimensão élfica. Te leva para o mundo dos mortos. Você está condenado a ficar lá por toda a eternidade ,GAMEOVER!')
             break


    elif op == 5:
      print(f'Você escolheu disitir da jornada, calma jogador todos tem medo o que vale é tentar!!!!!')
      break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3286980248.py in <cell line: 0>()
# ----> 1 nome = str(input('digite seu nome: '))
#       2
#       3 print(' 1 - Cavaleiro: um humano forte e corajoso com uma armadura poderosa e uma boa espada (seu objetivo é resgatar ''uma princesa)\n 2 - Mago: um feiticeiro poderoso, muito esperto e corajoso (seu objetivo é pegar uma pedra ''poderosa para os seus feitiços)\n 3 - Troll: uma criatura gigante e com uma força bruta gigantesca mais não ''muito esperto (seu objetivo não passa de um banquete com comida de sabor incrivel)\n 4 - Elfo: Criatura mística. Conhecidos por sua agilidade, sabedoria ancestral e habilidades mágicas. (Seu objetivo é recuperar um antigo artefato élfico, escondido em uma floresta encantada, que possui o poder de restaurar tudo o que quiser.)\n 5 - Desisitir da jornada!')
# ...
